# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # MLflow Regression Recipe Notebook
#
# This notebook runs the MLflow Regression Recipe on Databricks and inspects its results. For more information about the MLflow Regression Recipe, including usage examples, see the [Regression Recipe overview documentation](https://mlflow.org/docs/latest/recipes.html#regression-recipe) the [Regression Recipe API documentation](https://mlflow.org/docs/latest/python_api/mlflow.recipes.html#module-mlflow.recipes.regression.v1.recipe).

# %%
from mlflow.recipes import Recipe

r = Recipe(profile="local")
# Out:
# 2022/11/21 14:23:20 INFO mlflow.recipes.recipe: Creating MLflow Recipe 'regression' with profile: 'local'

# %%
r.clean()

# %%
r.inspect()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <body>
#     <style>
#       @keyframes spin {
#         to { transform: translate(calc(-50%), calc(50vh - 50%)) rotate(360deg); }
#       }
#       .mermaidTooltip {
#         display: none;
#       }
#       .wrapper {
#         display: flex;
#       }
#       .mermaid {
#         width: 60%;
#       }
#       .pane-loading {
#         font-size: 0;
#         color: transparent;
#       }
#       .pane-loading::after {
#         content: "";
#         position: absolute;
#         inset: 0 50%;
#         width: 32px;
#         height: 32px;
#         transform: translate(calc(-50%), calc(50vh - 50%));
#         border: 0.25rem solid #9370DB;
#         border-bottom: 0.25rem solid rgba(0,0,0,0);
#         border-radius: 50%;
#         animation: spin 1s linear infinite;
#       }
#       #editor {
#         font-size: 13px;
#         width: 40%;
#         position: relative;
#       }
#       font {
#         font-size: 24px;
#         padding: 24px;
#       }
#       .node:hover {
#         stroke: #2272B4 !important;
#         color: #0E538B !important;
#         background-color: #bbdaf4;
#       }
#     </style>
#
#     <div class="wrapper">
#       <div class="mermaid pane-loading">
#           flowchart TD
#
#           subgraph " "
#             recipe([recipe.yaml])
#
#             ingestUserCode([steps/ingest.py]) --> ingestMLPStep[["<font>ingest</font>"]]
#             ingestMLPStep --> dataParquet[(ingested_data)]
#
#             ingestScoringUserCode([steps/ingest.py]) --> ingestScoringMLPStep[["<font>ingest_scoring</font>"]]
#             ingestScoringMLPStep --> dataScoringParquet[(ingested_scoring_data)]
#
#             dataScoring[(ingested_scoring_data)] --> predictMLPStep[["<font>predict</font>"]]
#             predictMLPStep --> dataScored[(scored_data)]
#           end
#
#           data[(ingested_data)] --> splitStep[["<font>split</font>"]]
#           transformUserCode([steps/transform.py]) --> transformMLPStep
#           splitUserCode([steps/split.py]) --> splitStep
#           splitStep --> splitData0[(training_data)]
#           splitStep --> splitData1[(validation_data)]
#           splitStep --> splitData2[(test_data)]
#           splitData0 --> transformMLPStep[["<font>transform</font>"]]
#           splitData1 --> transformMLPStep[["<font>transform</font>"]]
#
#           transformMLPStep --> transformedParquet[(transformed_training_data, <br/> transformed_validation_data)]
#           transformMLPStep --> transformer
#           transformedParquet --> trainMLPStep[["<font>train</font>"]]
#
#           trainUserCode([steps/train.py]) --> trainMLPStep
#           customMetricsUserCode([steps/custom_metrics.py]) --> trainMLPStep
#           transformer --> trainMLPStep
#           trainMLPStep --> run
#           trainMLPStep --> model
#           trainMLPStep --> predictedTrainingData[(predicted_training_data)]
#
#           model --> evaluateMLPStep[["<font>evaluate</font>"]]
#           splitData1 --> evaluateMLPStep
#           splitData2 --> evaluateMLPStep
#           customMetricsUserCode --> evaluateMLPStep
#           evaluateMLPStep --> model_validation_status
#           run --> registerMLPStep[["<font>register</font>"]]
#           run --> evaluateMLPStep
#
#           model_validation_status --> registerMLPStep
#           registerMLPStep --> registered_model_version
#
#           click ingestMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;ingest&bsol;&#39; step resolves the dataset specified by the &bsol;&#39;steps.ingest&bsol;&#39; section in recipe.yaml and converts it to parquet format, leveraging the custom dataset parsing code defined in `steps/ingest.py` (and referred to by the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;steps.ingest&bsol;&#39; section in recipe.yaml) if necessary. Subsequent steps convert this dataset into training, validation, & test sets and use them to develop a model. An example recipe.yaml &bsol;&#39;steps.ingest&bsol;&#39; configuration is shown below.\n\nsteps.ingest:\n  location: https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2022-01.parquet\n  using: {{INGEST_DATA_FORMAT|default(&bsol;&#39;parquet&bsol;&#39;)}}\n  loader_method: load_file_as_dataframe\n', 'help_string_type': 'text'}"
#           click ingestUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/ingest.py defines customizable logic for parsing arbitrary dataset formats (i.e. formats that are not natively parsed by MLflow Recipes) via the `load_file_as_dataframe` function. Note that the Parquet, Delta, and Spark SQL dataset formats are natively parsed by MLflow Recipes, and you do not need to define custom logic for parsing them. An example `load_file_as_dataframe` implementation is displayed below (note that a different function name or module can be specified via the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;data&bsol;&#39; section in recipe.yaml).\n&bsol;#quot;&bsol;#quot;&bsol;#quot;\n\ndef load_file_as_dataframe(\n    file_path: str,\n    file_format: str,\n) -> pandas.DataFrame:\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n    Load content from the specified dataset file as a Pandas DataFrame.\n\n    This method is used to load dataset types that are not natively  managed by MLflow Recipes (datasets that are not in Parquet, Delta Table, or Spark SQL Table format). This method is called once for each file in the dataset, and MLflow Recipes automatically combines the resulting DataFrames together.\n\n    :param file_path: The path to the dataset file.\n    :param file_format: The file format string, such as &bsol;#quot;csv&bsol;#quot;.\n    :return: A Pandas DataFrame representing the content of the specified file.\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n', 'help_string_type': 'python'}"
#           click splitStep renderMoreInformation "{'help_string': 'The &bsol;&#39;split&bsol;&#39; step splits the ingested dataset produced by the &bsol;&#39;ingest&bsol;&#39; step into a training dataset for model training, a validation dataset for model performance evaluation & tuning, and a test dataset for model performance evaluation. The fraction of records allocated to each dataset is defined by the &bsol;&#39;split_ratios&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml. The split step also preprocesses the datasets using logic defined in `steps/split.py` (and referred to by the &bsol;&#39;post_split_method&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml). Subsequent steps use these datasets to develop a model and measure its performance. An example recipe.yaml &bsol;&#39;split&bsol;&#39; step definition is shown below.\n\nsteps:\n  split:\n    split_ratios: {{SPLIT_RATIOS|default([0.75, 0.125, 0.125])}}\n    post_split_filter_method: create_dataset_filter\n', 'help_string_type': 'text'}"
#           click transformMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;transform&bsol;&#39; step uses the training dataset produced by &bsol;&#39;split&bsol;&#39; to fit a transformer with the transformation operations defined in `steps/transform.py` (and referred to by the &bsol;&#39;transformer_method&bsol;&#39; attribute of the &bsol;&#39;transform&bsol;&#39; step definition in recipe.yaml). The transformer is then applied to the training dataset and the validation dataset, producing transformed datasets that are used by subsequent steps for estimator training and model performance evaluation. An example recipe.yaml &bsol;&#39;transform&bsol;&#39; step definition is shown below.\n\nsteps:\n  transform:\n    transformer_method: transformer_fn\n', 'help_string_type': 'text'}"
#           click transformUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/transform.py defines customizable logic for transforming input data during model inference. Transformations are specified via the via the `transformer_fn` function, an example of which is displayed below (note that a different function name or module can be specified via the &bsol;&#

# %%
r.run("ingest")
# Out:
# 2022/11/21 14:25:57 INFO mlflow.recipes.step: Running step ingest...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Ingest@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-ut34n4">
#
#                     <button id=0 class="tablink-ut34n4">
#                         Data Profile
#                     </button>
#
#                     <button id=1 class="tablink-ut34n4">
#                         Data Schema
#                     </button>
#
#                     <button id=2 class="tablink-ut34n4">
#                         Data Preview
#                     </button>
#
#                     <button id=3 class="tablink-ut34n4">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-ut34n4 content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-ut34n4 content-hide"><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_d9ff5 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_d9ff5  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_d9ff5  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_d9ff5" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_d9ff5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_d9ff5_level0_col1" class="col_heading level0 col1" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d9ff5_row0_col0" class="data row0 col0" >tpep_pickup_datetime</td>
#       <td id="T_d9ff5_row0_col1" class="data row0 col1" >datetime</td>
#     </tr>
#     <tr>
#       <td id="T_d9ff5_row1_col0" class="data row1 col0" >tpep_dropoff_datetime</td>
#       <td id="T_d9ff5_row1_col1" class="data row1 col1" >datetime</td>
#     </tr>
#     <tr>
#       <td id="T_d9ff5_row2_col0" class="data row2 col0" >trip_distance</td>
#       <td id="T_d9ff5_row2_col1" class="data row2 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_d9ff5_row3_col0" class="data row3 col0" >fare_amount</td>
#       <td id="T_d9ff5_row3_col1" class="data row3 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_d9ff5_row4_col0" class="data row4 col0" >pickup_zip</td>
#       <td id="T_d9ff5_row4_col1" class="data row4 col1" >integer</td>
#     </tr>
#     <tr>
#       <td id="T_d9ff5_row5_col0" class="data row5 col0" >dropoff_zip</td>
#       <td id="T_d9ff5_row5_col1" class="data row5 col1" >integer</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#
#                 <div class="content-ut34n4 content-hide"><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_8a743 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_8a743  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_8a743  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_8a743" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_8a743_level0_col0" class="col_heading level0 col0" >tpep_pickup_datetime</th>
#       <th id="T_8a743_level0_col1" class="col_heading level0 col1" >tpep_dropoff_datetime</th>
#       <th id="T_8a743_level0_col2" class="col_heading level0 col2" >trip_distance</th>
#       <th id="T_8a743_level0_col3" class="col_heading level0 col3" >fare_amount</th>
#       <th id="T_8a743_level0_col4" class="col_heading level0 col4" >pickup_zip</th>
#       <th id="T_8a743_level0_col5" class="col_heading level0 col5" >dropoff_zip</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8a743_row0_col0" class="data row0 col0" >2016-02-13 21:47:53</td>
#       <td id="T_8a743_row0_col1" class="data row0 col1" >2016-02-13 21:57:15</td>
#       <td id="T_8a743_row0_col2" class="data row0 col2" >1.400000</td>
#       <td id="T_8a743_row0_col3" class="data row0 col3" >8.000000</td>
#       <td id="T_8a743_row0_col4" class="data row0 col4" >10103</td>
#       <td id="T_8a743_row0_col5" class="data row0 col5" >10110</td>
#     </tr>
#     <tr>
#       <td id="T_8a743_row1_col0" class="data row1 col0" >2016-02-13 18:29:09</td>
#       <td id="T_8a743_row1_col1" class="data row1 col1" >2016-02-13 18:37:23</td>
#       <td id="T_8a743_row1_col2" class="data row1 col2" >1.310000</td>
#       <td id="T_8a743_row1_col3" class="data row1 col3" >7.500000</td>
#       <td id="T_8a743_row1_col4" class="data row1 col4" >10023</td>
#       <td id="T_8a743_row1_col5" class="data row1 col5" >10023</td>
#     </tr>
#     <tr>
#       <td id="T_8a743_row2_col0" class="data row2 col0" >2016-02-06 19:40:58</td>
#       <td id="T_8a743_row2_col1" class="data row2 col1" >2016-02-06 19:52:32</td>
#       <td id="T_8a743_row2_col2" class="data row2 col2" >1.800000</td>
#       <td id="T_8a743_row2_col3" class="data row2 col3" >9.500000</td>
#       <td id="T_8a743_row2_col4" class="data row2 col4" >10001</td>
#       <td id="T_8a743_row2_col5" class="data row2 col5" >10018</td>
#     </tr>
#     <tr>
#       <td id="T_8a743_row3_col0" class="data row3 col0" >2016-02-12 19:06:43</td>
#       <td id="T_8a743_row3_col1" class="data row3 col1" >2016-02-12 19:20:54</td>
#       <td id="T_8a743_row3_col2" class="data row3 col2" >2.300000</td>
#       <td id="T_8a743_row3_col3" class="data row3 col3" >11.500000</td>
#       <td id="T_8a743_row3_col4" class="data row3 col4" >10044</td>
#       <td id="T_8a743_row3_col5" class="data row3 col5" >10111</td>
#     </tr>
#     <tr>
#       <td id="T_8a743_row4_col0" class="data row4 col0" >2016-02-23 10:27:56</td>
#       <td id="T_8a743_row4_col1" class="data row4 col1" >2016-02-23 10:58:33</td>

# %%
r.run("split")
# Out:
# 2022/11/21 14:26:03 INFO mlflow.recipes.utils.execution: ingest: No changes. Skipping.
# 2022/11/21 14:26:05 INFO mlflow.recipes.step: Running step split...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Split@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-1t1aw9">
#
#                     <button id=0 class="tablink-1t1aw9">
#                         Compare Splits
#                     </button>
#
#                     <button id=1 class="tablink-1t1aw9">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-1t1aw9 content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-1t1aw9 content-hide">
#
#                 <p><strong>Number of train dataset rows:</strong> <code>8051</code></p>
#                 <p><strong>Number of validation dataset rows:</strong> <code>959</code></p>
#                 <p><strong>Number of test dataset rows:</strong> <code>990</code></p>
#                 <p><strong>Number of dropped rows:</strong> <code>0</code></p>
#                 <p><strong>Run duration (s)</strong>: 0.458</p>
#                 <p><strong>Last updated:</strong> 2022-11-21 14:26:05</p>
#                 </div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-1t1aw9");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-1t1aw9");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-1t1aw9")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-1t1aw9");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-1t1aw9");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>

# %%
r.run("transform")
# Out:
# 2022/11/21 14:26:11 INFO mlflow.recipes.utils.execution: ingest, split: No changes. Skipping.
# 2022/11/21 14:26:13 INFO mlflow.recipes.step: Running step transform...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Transform@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-pnjlo8">
#
#                     <button id=0 class="tablink-pnjlo8">
#                         Data Profile (Train Transformed)
#                     </button>
#
#                     <button id=1 class="tablink-pnjlo8">
#                         Transformer
#                     </button>
#
#                     <button id=2 class="tablink-pnjlo8">
#                         Input Schema
#                     </button>
#
#                     <button id=3 class="tablink-pnjlo8">
#                         Output Schema
#                     </button>
#
#                     <button id=4 class="tablink-pnjlo8">
#                         Data Preview
#                     </button>
#
#                     <button id=5 class="tablink-pnjlo8">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-pnjlo8 content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-pnjlo8 content-hide"><style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-color: white;}#sk-container-id-1 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-1 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-1 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-1 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-1 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-1 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-1 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-width: 100%;overflow: auto;}#sk-container-id-1 input.sk-toggleable__control:checked~label.sk-toggleable__label-arrow:before {content: "▾";}#sk-container-id-1 div.sk-estimator input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-label input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 input.sk-hidden--visually {border: 0;clip: rect(1px 1px 1px 1px);clip: rect(1px, 1px, 1px, 1px);height: 1px;margin: -1px;overflow: hidden;padding: 0;position: absolute;width: 1px;}#sk-container-id-1 div.sk-estimator {font-family: monospace;background-color: #f0f8ff;border: 1px dotted black;border-radius: 0.25em;box-sizing: border-box;margin-bottom: 0.5em;}#sk-container-id-1 div.sk-estimator:hover {background-color: #d4ebff;}#sk-container-id-1 div.sk-parallel-item::after {content: "";width: 100%;border-bottom: 1px solid gray;flex-grow: 1;}#sk-container-id-1 div.sk-label:hover label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-serial::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: 0;}#sk-container-id-1 div.sk-serial {display: flex;flex-direction: column;align-items: center;background-color: white;padding-right: 0.2em;padding-left: 0.2em;position: relative;}#sk-container-id-1 div.sk-item {position: relative;z-index: 1;}#sk-container-id-1 div.sk-parallel {display: flex;align-items: stretch;justify-content: center;background-color: white;position: relative;}#sk-container-id-1 div.sk-item::before, #sk-container-id-1 div.sk-parallel-item::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: -1;}#sk-container-id-1 div.sk-parallel-item {display: flex;flex-direction: column;z-index: 1;position: relative;background-color: white;}#sk-container-id-1 div.sk-parallel-item:first-child::after {align-self: flex-end;width: 50%;}#sk-container-id-1 div.sk-parallel-item:last-child::after {align-self: flex-start;width: 50%;}#sk-container-id-1 div.sk-parallel-item:only-child::after {width: 0;}#sk-container-id-1 div.sk-dashed-wrapped {border: 1px dashed gray;margin: 0 0.4em 0.5em 0.4em;box-sizing: border-box;padding-bottom: 0.4em;background-color: white;}#sk-container-id-1 div.sk-label label {font-family: monospace;font-weight: bold;display: inline-block;line-height: 1.2em;}#sk-container-id-1 div.sk-label-container {text-align: center;}#sk-container-id-1 div.sk-container {/* jupyter's `normalize.less` sets `[hidden] { display: none; }` but bootstrap.min.css set `[hidden] { display: none !important; }` so we also need the `!important` here to be able to override the default hidden behavior on the sphinx rendered scikit-learn.org. See: https://github.com/scikit-learn/scikit-learn/issues/21755 */display: inline-block !important;position: rela ...
#                  FunctionTransformer(feature_names_out=&#x27;one-to-one&#x27;,
#                                      func=&lt;function calculate_features at 0x7fcb32fb5000&gt;)),

# %%
r.run("train")
# Out:
# 2022/11/21 14:26:20 INFO mlflow.recipes.utils.execution: ingest, split, transform: No changes. Skipping.
# 2022/11/21 14:26:21 INFO mlflow.recipes.step: Running step train...
# [flaml.automl: 11-21 14:26:30] {2599} INFO - task = regression
# [flaml.automl: 11-21 14:26:30] {2601} INFO - Data split method: uniform
# [flaml.automl: 11-21 14:26:30] {2604} INFO - Evaluation method: holdout
# [flaml.automl: 11-21 14:26:30] {2726} INFO - Minimizing error metric: rmse
# [flaml.automl: 11-21 14:26:30] {2870} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl: 11-21 14:26:30] {3166} INFO - iteration 0, current learner lgbm
# [flaml.automl: 11-21 14:26:30] {3296} INFO - Estimated sufficient time budget=850s. Estimated necessary time budget=6s.
# [flaml.automl: 11-21 14:26:31] {3343} INFO -  at 0.2s,	estimator lgbm's best error=3.8716,	best estimator lgbm's best error=3.8716
# [flaml.automl: 11-21 14:26:31] {3166} INFO - iteration 1, current learner lgbm
# [flaml.automl: 11-21 14:26:31] {3343} INFO -  at 0.9s,	estimator lgbm's best error=3.8716,	best estimator lgbm's best error=3.8716
# [flaml.automl: 11-21 14:26:31] {3166} INFO - iteration 2, current learner lgbm
# [flaml.automl: 11-21 14:26:31] {3343} INFO -  at 0.9s,	estimator lgbm's best error=3.8623,	best estimator lgbm's best error=3.8623
# [flaml.automl: 11-21 14:26:31] {3166} INFO - iteration 3, current learner lgbm
# [flaml.automl: 11-21 14:26:32] {3343} INFO -  at 1.5s,	estimator lgbm's best error=3.8487,	best estimator lgbm's best error=3.8487
# [flaml.automl: 11-21 14:26:32] {3166} INFO - iteration 4, current learner lgbm
# [flaml.automl: 11-21 14:26:32] {3343} INFO -  at 2.1s,	estimator lgbm's best error=3.8487,	best estimator lgbm's best error=3.8487
# [flaml.automl: 11-21 14:26:32] {3166} INFO - iteration 5, current learner lgbm
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 2.2s,	estimator lgbm's best error=3.8232,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 6, current learner lgbm
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 2.8s,	estimator lgbm's best error=3.8232,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 7, current learner lgbm
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 2.8s,	estimator lgbm's best error=3.8232,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 8, current learner lgbm
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 2.9s,	estimator lgbm's best error=3.8232,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 9, current learner xgboost
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 3.2s,	estimator xgboost's best error=4.2612,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 10, current learner lgbm
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 3.2s,	estimator lgbm's best error=3.8232,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 11, current learner extra_tree
# [flaml.automl: 11-21 14:26:33] {3343} INFO -  at 3.3s,	estimator extra_tree's best error=3.8672,	best estimator lgbm's best error=3.8232
# [flaml.automl: 11-21 14:26:33] {3166} INFO - iteration 12, current learner extra_tree
# [flaml.automl: 11-21 14:26:34] {3343} INFO -  at 3.3s,	estimator extra_tree's best error=3.8206,	best estimator extra_tree's best error=3.8206
# [flaml.automl: 11-21 14:26:34] {3166} INFO - iteration 13, current learner extra_tree
# [flaml.automl: 11-21 14:26:34] {3343} INFO -  at 3.9s,	estimator extra_tree's best error=3.8206,	best estimator extra_tree's best error=3.8206
# [flaml.automl: 11-21 14:26:34] {3166} INFO - iteration 14, current learner extra_tree
# [flaml.automl: 11-21 14:26:34] {3343} INFO -  at 4.0s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:34] {3166} INFO - iteration 15, current learner lgbm
# [flaml.automl: 11-21 14:26:34] {3343} INFO -  at 4.6s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:34] {3166} INFO - iteration 16, current learner extra_tree
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 4.7s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 17, current learner lgbm
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 4.7s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 18, current learner extra_tree
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 4.8s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 19, current learner rf
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 4.9s,	estimator rf's best error=3.8568,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 20, current learner rf
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.0s,	estimator rf's best error=3.8359,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 21, current learner rf
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.0s,	estimator rf's best error=3.8359,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 22, current learner lgbm
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.0s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 23, current learner lgbm
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.0s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 24, current learner extra_tree
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.1s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.2s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 26, current learner rf
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.4s,	estimator rf's best error=3.8322,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 27, current learner xgboost
# [flaml.automl: 11-21 14:26:35] {3343} INFO -  at 5.5s,	estimator xgboost's best error=4.2612,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:35] {3166} INFO - iteration 28, current learner extra_tree
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.7s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 29, current learner extra_tree
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.8s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 30, current learner lgbm
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.8s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 31, current learner lgbm
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.8s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 32, current learner lgbm
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.8s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 33, current learner extra_tree
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.9s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 34, current learner lgbm
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.9s,	estimator lgbm's best error=3.8232,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 35, current learner xgboost
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 5.9s,	estimator xgboost's best error=3.9752,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 36, current learner extra_tree
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 6.1s,	estimator extra_tree's best error=3.8177,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 37, current learner xgboost
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 6.1s,	estimator xgboost's best error=3.8235,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 38, current learner xgboost
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 6.1s,	estimator xgboost's best error=3.8235,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 39, current learner xgboost
# [flaml.automl: 11-21 14:26:36] {3343} INFO -  at 6.2s,	estimator xgboost's best error=3.8235,	best estimator extra_tree's best error=3.8177
# [flaml.automl: 11-21 14:26:36] {3166} INFO - iteration 40, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 6.2s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 41, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 6.9s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 42, current learner lgbm
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 6.9s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 43, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.1s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.1s,	estimator extra_tree's best error=3.8177,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 45, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.3s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 46, current learner lgbm
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.5s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 47, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.6s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 48, current learner lgbm
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.6s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 49, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.6s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 50, current learner xgboost
# [flaml.automl: 11-21 14:26:37] {3343} INFO -  at 7.7s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:37] {3166} INFO - iteration 51, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.7s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 52, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.7s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 53, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.7s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 54, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.8s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 55, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.8s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 56, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.8s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 57, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.8s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 58, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.9s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 59, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 7.9s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 60, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.0s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 61, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.0s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 62, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.1s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 63, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.2s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 64, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.2s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 65, current learner rf
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.3s,	estimator rf's best error=3.8322,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 66, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.3s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 67, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.4s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 68, current learner lgbm
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.4s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 69, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.4s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 70, current learner xgboost
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.5s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 71, current learner rf
# [flaml.automl: 11-21 14:26:38] {3343} INFO -  at 8.6s,	estimator rf's best error=3.8322,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:38] {3166} INFO - iteration 72, current learner extra_tree
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.7s,	estimator extra_tree's best error=3.8177,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 73, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.7s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 74, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.8s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 75, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.8s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 76, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.9s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 77, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.9s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 78, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 8.9s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 79, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.0s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 80, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.1s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 81, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.2s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 82, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.2s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 83, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.3s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 84, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.3s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 85, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.4s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 86, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.4s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 87, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.4s,	estimator lgbm's best error=3.8232,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 88, current learner lgbm
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.4s,	estimator lgbm's best error=3.8224,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 89, current learner extra_tree
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.5s,	estimator extra_tree's best error=3.8177,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 90, current learner xgboost
# [flaml.automl: 11-21 14:26:39] {3343} INFO -  at 9.6s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:39] {3166} INFO - iteration 91, current learner extra_tree
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 9.7s,	estimator extra_tree's best error=3.8177,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 92, current learner xgboost
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 9.8s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 93, current learner xgboost
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 9.8s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 94, current learner xgboost
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 9.9s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 95, current learner extra_tree
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 9.9s,	estimator extra_tree's best error=3.8177,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 96, current learner xgboost
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 10.0s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 97, current learner xgboost
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 10.0s,	estimator xgboost's best error=3.8078,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3166} INFO - iteration 98, current learner xgb_limitdepth
# [flaml.automl: 11-21 14:26:40] {3343} INFO -  at 10.0s,	estimator xgb_limitdepth's best error=4.2959,	best estimator xgboost's best error=3.8078
# [flaml.automl: 11-21 14:26:40] {3602} INFO - retrain xgboost for 0.0s
# [flaml.automl: 11-21 14:26:40] {3609} INFO - retrained model: XGBRegressor(base_score=0.5, booster='gbtree', callbacks=[],
#              colsample_bylevel=1.0, colsample_bynode=1, colsample_bytree=1.0,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints='', learning_rate=1.0, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=0, max_leaves=4, min_child_weight=5.909231502320289,
#              missing=nan, monotone_constraints='()', n_estimators=10, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)
# [flaml.automl: 11-21 14:26:40] {2901} INFO - fit succeeded
# [flaml.automl: 11-21 14:26:40] {2902} INFO - Time taken to find the best model: 6.222285985946655
# 2022/11/21 14:26:40 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2022/11/21 14:26:40 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2022/11/21 14:26:40 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.
# 2022/11/21 14:26:50 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2022/11/21 14:27:05 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/21 14:27:06 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Train@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-nlp81w">
#
#                     <button id=0 class="tablink-nlp81w">
#                         Model Performance
#                     </button>
#
#                     <button id=1 class="tablink-nlp81w">
#                         Data Profile (Predictions)
#                     </button>
#
#                     <button id=2 class="tablink-nlp81w">
#                         Model Architecture
#                     </button>
#
#                     <button id=3 class="tablink-nlp81w">
#                         Model Schema
#                     </button>
#
#                     <button id=4 class="tablink-nlp81w">
#                         Worst Predictions
#                     </button>
#
#                     <button id=5 class="tablink-nlp81w">
#                         Data Profile (Worst vs Train)
#                     </button>
#
#                     <button id=6 class="tablink-nlp81w">
#                         Leaderboard
#                     </button>
#
#                     <button id=7 class="tablink-nlp81w">
#                         Best Parameters  (AutoML)
#                     </button>
#
#                     <button id=8 class="tablink-nlp81w">
#                         Warning Logs
#                     </button>
#
#                     <button id=9 class="tablink-nlp81w">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-nlp81w content-hide"><h3 class='section-title'>Summary Metrics (Validation)</h3><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_5f4a5 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_5f4a5  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_5f4a5  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_5f4a5_row0_col0, #T_5f4a5_row0_col1, #T_5f4a5_row0_col2, #T_5f4a5_row1_col0, #T_5f4a5_row1_col1, #T_5f4a5_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5f4a5" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_5f4a5_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_5f4a5_level0_col1" class="col_heading level0 col1" >training</th>
#       <th id="T_5f4a5_level0_col2" class="col_heading level0 col2" >validation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f4a5_row0_col0" class="data row0 col0" >root_mean_squared_error</td>
#       <td id="T_5f4a5_row0_col1" class="data row0 col1" >3.43453</td>
#       <td id="T_5f4a5_row0_col2" class="data row0 col2" >3.86595</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row1_col0" class="data row1 col0" >weighted_mean_squared_error</td>
#       <td id="T_5f4a5_row1_col1" class="data row1 col1" >11.312</td>
#       <td id="T_5f4a5_row1_col2" class="data row1 col2" >14.9799</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row2_col0" class="data row2 col0" >example_count</td>
#       <td id="T_5f4a5_row2_col1" class="data row2 col1" >8051</td>
#       <td id="T_5f4a5_row2_col2" class="data row2 col2" >959</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row3_col0" class="data row3 col0" >max_error</td>
#       <td id="T_5f4a5_row3_col1" class="data row3 col1" >27.3936</td>
#       <td id="T_5f4a5_row3_col2" class="data row3 col2" >20.823</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row4_col0" class="data row4 col0" >mean_absolute_error</td>
#       <td id="T_5f4a5_row4_col1" class="data row4 col1" >2.14017</td>
#       <td id="T_5f4a5_row4_col2" class="data row4 col2" >2.35457</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row5_col0" class="data row5 col0" >mean_absolute_percentage_error</td>
#       <td id="T_5f4a5_row5_col1" class="data row5 col1" >4.72359e+13</td>
#       <td id="T_5f4a5_row5_col2" class="data row5 col2" >5.46936e+13</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row6_col0" class="data row6 col0" >mean_on_target</td>
#       <td id="T_5f4a5_row6_col1" class="data row6 col1" >2.86689</td>
#       <td id="T_5f4a5_row6_col2" class="data row6 col2" >3.13932</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row7_col0" class="data row7 col0" >mean_squared_error</td>
#       <td id="T_5f4a5_row7_col1" class="data row7 col1" >11.796</td>
#       <td id="T_5f4a5_row7_col2" class="data row7 col2" >14.9456</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row8_col0" class="data row8 col0" >r2_score</td>
#       <td id="T_5f4a5_row8_col1" class="data row8 col1" >0.0277288</td>
#       <td id="T_5f4a5_row8_col2" class="data row8 col2" >-0.0180791</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row9_col0" class="data row9 col0" >score</td>
#       <td id="T_5f4a5_row9_col1" class="data row9 col1" >0.0277288</td>
#       <td id="T_5f4a5_row9_col2" class="data row9 col2" >-0.0180791</td>
#     </tr>
#     <tr>
#       <td id="T_5f4a5_row10_col0" class="data row10 col0" >sum_on_target</td>
#       <td id="T_5f4a5_row10_col1" class="data row10 col1" >23081.4</td>
#       <td id="T_5f4a5_row10_col2" class="data row10 col2" >3010.61</td>
#     </tr>
#   </tbody>
# </table>
# </div> </div>
#
#                 <div class="content-nlp81w content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-nlp81w content-hide"><style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {backg

# %%
r.run("evaluate")
# Out:
# 2022/11/21 14:28:41 INFO mlflow.recipes.utils.execution: ingest, split, transform, train: No changes. Skipping.
# 2022/11/21 14:28:43 INFO mlflow.recipes.step: Running step evaluate...
# 2022/11/21 14:28:49 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/21 14:29:10 INFO mlflow.models.evaluation.default_evaluator: Shap explainer _PatchedKernelExplainer is used.
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  4.62it/s]
#  40%|████      | 4/10 [00:00<00:00, 12.27it/s]
#  60%|██████    | 6/10 [00:00<00:00, 13.77it/s]
#  80%|████████  | 8/10 [00:00<00:00, 13.30it/s]
# 100%|██████████| 10/10 [00:00<00:00, 13.52it/s]
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# 2022/11/21 14:30:27 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Evaluate@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-8yltao">
#
#                     <button id=0 class="tablink-8yltao">
#                         Model Performance (Test)
#                     </button>
#
#                     <button id=1 class="tablink-8yltao">
#                         Model Validation
#                     </button>
#
#                     <button id=2 class="tablink-8yltao">
#                         Feature Importance
#                     </button>
#
#                     <button id=3 class="tablink-8yltao">
#                         Warning Logs
#                     </button>
#
#                     <button id=4 class="tablink-8yltao">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-8yltao content-hide"><h3 class='section-title'>Summary Metrics</h3><b>NOTE</b>: Use evaluation metrics over test dataset with care. Fine-tuning model over the test dataset is not advised.<div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_fbcd4 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_fbcd4  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_fbcd4  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_fbcd4_row0_col0, #T_fbcd4_row0_col1, #T_fbcd4_row0_col2, #T_fbcd4_row1_col0, #T_fbcd4_row1_col1, #T_fbcd4_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_fbcd4" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_fbcd4_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_fbcd4_level0_col1" class="col_heading level0 col1" >validation</th>
#       <th id="T_fbcd4_level0_col2" class="col_heading level0 col2" >test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fbcd4_row0_col0" class="data row0 col0" >root_mean_squared_error</td>
#       <td id="T_fbcd4_row0_col1" class="data row0 col1" >3.86595</td>
#       <td id="T_fbcd4_row0_col2" class="data row0 col2" >3.478859</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row1_col0" class="data row1 col0" >weighted_mean_squared_error</td>
#       <td id="T_fbcd4_row1_col1" class="data row1 col1" >14.9799</td>
#       <td id="T_fbcd4_row1_col2" class="data row1 col2" >11.770481</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row2_col0" class="data row2 col0" >example_count</td>
#       <td id="T_fbcd4_row2_col1" class="data row2 col1" >959</td>
#       <td id="T_fbcd4_row2_col2" class="data row2 col2" >990.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row3_col0" class="data row3 col0" >max_error</td>
#       <td id="T_fbcd4_row3_col1" class="data row3 col1" >20.823</td>
#       <td id="T_fbcd4_row3_col2" class="data row3 col2" >21.848149</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row4_col0" class="data row4 col0" >mean_absolute_error</td>
#       <td id="T_fbcd4_row4_col1" class="data row4 col1" >2.35457</td>
#       <td id="T_fbcd4_row4_col2" class="data row4 col2" >2.147404</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row5_col0" class="data row5 col0" >mean_absolute_percentage_error</td>
#       <td id="T_fbcd4_row5_col1" class="data row5 col1" >5.46936e+13</td>
#       <td id="T_fbcd4_row5_col2" class="data row5 col2" >38046733520674.171875</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row6_col0" class="data row6 col0" >mean_on_target</td>
#       <td id="T_fbcd4_row6_col1" class="data row6 col1" >3.13932</td>
#       <td id="T_fbcd4_row6_col2" class="data row6 col2" >2.836010</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row7_col0" class="data row7 col0" >mean_squared_error</td>
#       <td id="T_fbcd4_row7_col1" class="data row7 col1" >14.9456</td>
#       <td id="T_fbcd4_row7_col2" class="data row7 col2" >12.102463</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row8_col0" class="data row8 col0" >r2_score</td>
#       <td id="T_fbcd4_row8_col1" class="data row8 col1" >-0.0180791</td>
#       <td id="T_fbcd4_row8_col2" class="data row8 col2" >-0.001537</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row9_col0" class="data row9 col0" >score</td>
#       <td id="T_fbcd4_row9_col1" class="data row9 col1" >-0.0180791</td>
#       <td id="T_fbcd4_row9_col2" class="data row9 col2" >-0.001537</td>
#     </tr>
#     <tr>
#       <td id="T_fbcd4_row10_col0" class="data row10 col0" >sum_on_target</td>
#       <td id="T_fbcd4_row10_col1" class="data row10 col1" >3010.61</td>
#       <td id="T_fbcd4_row10_col2" class="data row10 col2" >2807.650000</td>
#     </tr>
#   </tbody>
# </table>
# </div> </div>
#
#                 <div class="content-8yltao content-hide"><h3 class='section-title'>Model Validation Results (Test Dataset)</h3> <div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_91bd6 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_91bd6  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_91bd6  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_91bd6" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_91bd6_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_91bd6_level0_col1" class="col_heading level0 col1" >greater_is_better</th>
#       <th id="T_91bd6_level0_col2" class="col_heading level0 col2" >value</th>
#       <th id="T_91bd6_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_91bd6_level0_col4" class="col_heading level0 col4" >validated</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_91bd6_row0_col0" class="data row0 col0" >root_mean_squared_error</td>
#       <td id="T_91bd6_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_91bd6_row0_col2" class="data row0 col2" >3.47886</td>
#       <td id="T_91bd6_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_91bd6_row0_col4" class="data row0 col4" >✅</td>
#     </tr>
#     <tr>
#       <td id="T_91bd6_row1_col0" class="data row1 col0" >mean_absolute_error</td>
#       <td id="T_91bd6_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_91bd6_row1_col2" class="data row1 col2" >2.1474</td>
#       <td id="T_91bd6_row1_col3" class="data row1 col3" >50</td>
#       <td id="T_91bd6_

# %%
r.run("register")
# Out:
# 2022/11/18 19:07:22 INFO mlflow.recipes.utils.execution: ingest, split, transform, train, evaluate: No changes. Skipping.
# 2022/11/18 19:07:30 INFO mlflow.recipes.step: Running step register...
# Successfully registered model 'taxi_fare_regressor'.
# 2022/11/18 19:07:31 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: taxi_fare_regressor, version 1
# Created version '1' of model 'taxi_fare_regressor'.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Register@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-0j9quc">
#
#                     <button id=0 class="tablink-0j9quc">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-0j9quc content-hide"><p><strong>Model Name:</strong> <code>taxi_fare_regressor</code></p><p><strong>Model Version:</strong> <code>1</code></p><p><strong>Model Source URI:</strong> <code>runs:/a41e16bbcfbc412fa018765763dbe35a/train/model</code></p><p><strong>Run duration (s)</strong>: 1.57</p><p><strong>Last updated:</strong> 2022-11-18 19:07:31</p></div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-0j9quc");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-0j9quc");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-0j9quc")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-0j9quc");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-0j9quc");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>

# %%
r.inspect("train")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Train@regression</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-e1hh2o">
#
#                     <button id=0 class="tablink-e1hh2o">
#                         Model Performance
#                     </button>
#
#                     <button id=1 class="tablink-e1hh2o">
#                         Data Profile (Predictions)
#                     </button>
#
#                     <button id=2 class="tablink-e1hh2o">
#                         Model Architecture
#                     </button>
#
#                     <button id=3 class="tablink-e1hh2o">
#                         Model Schema
#                     </button>
#
#                     <button id=4 class="tablink-e1hh2o">
#                         Worst Predictions
#                     </button>
#
#                     <button id=5 class="tablink-e1hh2o">
#                         Data Profile (Worst vs Train)
#                     </button>
#
#                     <button id=6 class="tablink-e1hh2o">
#                         Leaderboard
#                     </button>
#
#                     <button id=7 class="tablink-e1hh2o">
#                         Best Parameters  (AutoML)
#                     </button>
#
#                     <button id=8 class="tablink-e1hh2o">
#                         Warning Logs
#                     </button>
#
#                     <button id=9 class="tablink-e1hh2o">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-e1hh2o content-hide"><h3 class='section-title'>Summary Metrics (Validation)</h3><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_4815e table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_4815e  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_4815e  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_4815e_row0_col0, #T_4815e_row0_col1, #T_4815e_row0_col2, #T_4815e_row1_col0, #T_4815e_row1_col1, #T_4815e_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4815e" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_4815e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_4815e_level0_col1" class="col_heading level0 col1" >training</th>
#       <th id="T_4815e_level0_col2" class="col_heading level0 col2" >validation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4815e_row0_col0" class="data row0 col0" >root_mean_squared_error</td>
#       <td id="T_4815e_row0_col1" class="data row0 col1" >4.03495</td>
#       <td id="T_4815e_row0_col2" class="data row0 col2" >3.08811</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row1_col0" class="data row1 col0" >weighted_mean_squared_error</td>
#       <td id="T_4815e_row1_col1" class="data row1 col1" >3.86282</td>
#       <td id="T_4815e_row1_col2" class="data row1 col2" >7.96016</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row2_col0" class="data row2 col0" >example_count</td>
#       <td id="T_4815e_row2_col1" class="data row2 col1" >8051</td>
#       <td id="T_4815e_row2_col2" class="data row2 col2" >959</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row3_col0" class="data row3 col0" >max_error</td>
#       <td id="T_4815e_row3_col1" class="data row3 col1" >220.146</td>
#       <td id="T_4815e_row3_col2" class="data row3 col2" >54.6742</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row4_col0" class="data row4 col0" >mean_absolute_error</td>
#       <td id="T_4815e_row4_col1" class="data row4 col1" >0.768177</td>
#       <td id="T_4815e_row4_col2" class="data row4 col2" >0.930729</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row5_col0" class="data row5 col0" >mean_absolute_percentage_error</td>
#       <td id="T_4815e_row5_col1" class="data row5 col1" >5.73633e+13</td>
#       <td id="T_4815e_row5_col2" class="data row5 col2" >0.079724</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row6_col0" class="data row6 col0" >mean_on_target</td>
#       <td id="T_4815e_row6_col1" class="data row6 col1" >12.3947</td>
#       <td id="T_4815e_row6_col2" class="data row6 col2" >13.1517</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row7_col0" class="data row7 col0" >mean_squared_error</td>
#       <td id="T_4815e_row7_col1" class="data row7 col1" >16.2809</td>
#       <td id="T_4815e_row7_col2" class="data row7 col2" >9.53643</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row8_col0" class="data row8 col0" >r2_score</td>
#       <td id="T_4815e_row8_col1" class="data row8 col1" >0.860647</td>
#       <td id="T_4815e_row8_col2" class="data row8 col2" >0.91975</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row9_col0" class="data row9 col0" >score</td>
#       <td id="T_4815e_row9_col1" class="data row9 col1" >0.860647</td>
#       <td id="T_4815e_row9_col2" class="data row9 col2" >0.91975</td>
#     </tr>
#     <tr>
#       <td id="T_4815e_row10_col0" class="data row10 col0" >sum_on_target</td>
#       <td id="T_4815e_row10_col1" class="data row10 col1" >99789.8</td>
#       <td id="T_4815e_row10_col2" class="data row10 col2" >12612.5</td>
#     </tr>
#   </tbody>
# </table>
# </div> </div>
#
#                 <div class="content-e1hh2o content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-e1hh2o content-hide"><style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-

# %%
training_data = r.get_artifact("training_data")
training_data.describe()

# %%
trained_model = r.get_artifact("model")
print(trained_model)
